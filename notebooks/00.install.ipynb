# %%
! pip install -r ../requirements.txt
# Out:
# ...
#   Obtaining dependency information for azure-ai-documentintelligence from https://files.pythonhosted.org/packages/61/b0/5283da4b3249c0b9d4c69ab0be714b359864b246a5b7c2fc9aae60362030/azure_ai_documentintelligence-1.0.0b3-py3-none-any.whl.metadata
#   Using cached azure_ai_documentintelligence-1.0.0b3-py3-none-any.whl.metadata (40 kB)
# ...
# Using cached azure_ai_documentintelligence-1.0.0b3-py3-none-any.whl (165 kB)
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
